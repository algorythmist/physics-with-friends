# %% [markdown]
# # QFT for the Gifted Amateur - Chapter 17 Exercises
#
# $
# \newcommand{\ket}[1]{\left|{#1}\right\rangle}
# \newcommand{\bra}[1]{\left\langle{#1}\right|}
# \newcommand{\braket}[2]{\left\langle{#1}\middle|{#2}\right\rangle}
# $

# %% [markdown]
# $$
# \Delta(x,y) \equiv \bra{0}T\phi(x)\phi^\dagger(y)\ket{0}
# $$

# %% [markdown]
# ### Exercise 17.1
#
# #### Solution
